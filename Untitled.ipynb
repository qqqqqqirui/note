# %%
import numpy

means=[]
for i in range(200):
    Data=numpy.random.f(1, 48, 100)
    means.append(numpy.mean(Data))
means
# Out:
# [1.0273985209650363,
#  0.8507899785069607,
#  1.2313259273072787,
#  0.955297072983889,
#  1.082403135369474,
#  0.9682584190893269,
#  0.8525843699176224,
#  1.256637648114333,
#  1.223339507049661,
#  1.1002352765356433,
#  1.0543378850122722,
#  1.2320581106197643,
#  0.8870467296949287,
#  1.2208632937113755,
#  1.2033769582799432,
#  0.6907885862142122,
#  1.267288331895175,
#  1.1031277607370027,
#  0.9598051878462935,
#  1.0266776659185077,
#  1.0549615275713402,
#  0.9400599748197805,
#  1.2417457931192646,
#  0.8803146749337379,
#  0.9931813340552386,
#  1.285823673810394,
#  1.1706759432427007,
#  1.169158582895048,
#  1.1610616390396344,
#  0.9251790821220064,
#  0.9963197071686001,
#  1.1357175663251646,
#  1.0747860453142473,
#  0.9912555233926185,
#  0.8751338109570876,
#  1.1079703027248093,
#  0.9828285132576521,
#  1.418982575733401,
#  1.3103740422542,
#  0.6821456990783912,
#  1.2380718231961543,
#  0.8686784497644129,
#  1.2222188039338813,
# ...

# %% [markdown]
# 样本均值直方图如下：

# %%
import matplotlib.pyplot as plt

plt.hist(means, bins=20)

plt.show()
