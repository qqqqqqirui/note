# %% [markdown]
# ### Lanzhou University
# ### INFO 250: Information Visualization (Fall, 2024)
# ---
#
# ## Project Proposal
#
# ## Project Title:Chart visualization analysis
#
# ## Team ID:26 (Class 2)
#
# ## Student(s):Sihan Li, Qirui Zhang, Chenbang You,Boyuan Chen
# ---
#  Date:2024/12/13
# ---

# %% [markdown]
# # Introduction
# -----
#
# In today's societal context, with the increasing economic downturn pressure, the incidence of global anxiety and depression is rising year by year, making the treatment of depression an increasingly important public health issue. The pathogenesis of depression is quite complex, involving multiple biological, psychological, and socio-environmental factors. Therefore, there are various medical治疗方案 for depression, commonly including pharmacological treatment and psychotherapy.
#
# In the pharmacological treatment of depression, recent research has begun to focus on the molecular mechanisms of depression and explore new therapeutic targets. DAPK1 and Glu2B are two proteins that play significant roles in the pathophysiology of depression and are considered potential targets for structure-based discovery of new antidepressants. The interaction of death-associated protein kinase 1 (DAPK1) with the 2B subunit (GluN2B) C-terminus of N-methyl-D-aspartate receptor (NMDAR) is critical in the pathophysiology of depression and is considered a potential target for the structure-based discovery of new antidepressants. We noticed that researchers from Zhejiang University and Chongqing University published a study in 2018 on the simulation of the interaction between DAPK1 and Glu2B, titled "Prediction of GluN2B-CT1290-1310/DAPK1 Interaction by Protein–Peptide Docking and Molecular Dynamics Simulation" [1]. This paper primarily used computational methods such as protein-peptide docking and molecular dynamics (MD) simulation to predict the mechanism of interaction between DAPK1 and the C-terminal residues 1290-1310 of Glu2B, and through residue free energy decomposition and alanine scanning analysis, identified the hot spots between the DAPK1 and Glu2B-CT1290-1310 complex. The study revealed the mechanism of GluN2B-CT1290-1310/DAPK1 interaction and provided insights for the structure-based discovery of drugs with this new binding mechanism.
#
# Furthermore, we carefully read this paper and identified areas that require improvement in visualizing the experimental results, and we have proposed our suggestions for improvement.

# %% [markdown]
# # Background of Selected Visualization
# -------
#
# When reviewing the aforementioned paper, we observed that the researchers initially conducted per-residue binding free energy decomposition calculations for the simulated DAPK1 and Glu2B-CT1290-1310 complex, obtaining separate energy contribution estimates for 21 major residues of the simulated DAPK1-Glu2B complex. Based on the results of the per-residue binding energy decomposition of the simulated complex, the researchers identified the nine hotspot residues with the greatest contributions. Subsequently, the researchers performed alanine scanning on the selected nine hotspot residues to obtain their binding free energies. Finally, the researchers绘制d bar charts for both the per-residue binding energy decomposition results of the simulated complex and the binding free energies of the hotspot residues obtained from alanine scanning, placing one above the other for comparative verification.
#
# As shown in the figure below, the chart is divided into two parts: the upper and lower halves.
# The upper half of the chart's orange bar graph displays the 21 major residues of the simulated DAPK1-Glu2B complex, with estimated energy contributions calculated using the per-residue binding energy decomposition method. Each residue's calculated absolute binding free energy value (absolute value) exceeded 0.60 kcal/mol, which are: Gly20, Val27, Glu100, Lys141, Glu143, Met146, Ile160, Asp161, Arg302, Gln1291, Asn1294, Leu1298, Arg1300, His1302, Ser1303, Tyr1304, Asp1305. Among them, Glu100, Gln1291, and Arg1300 had the most significant contributions, with values of -5.85 kcal/mol, -6.36 kcal/mol, and -5.92 kcal/mol, respectively. The combined energy contribution of these residues accounts for 78% of the total binding free energy, leading the article to conclude that these residues are key parts of the DAPK1-Glu2B complex.
#
# The lower half of the chart's black bar graph illustrates the binding free energies of the hotspot residues determined by alanine scanning of the DAPK1-Glu2B complex interface, with each residue's absolute binding free energy value (absolute value) exceeding 2 kcal/mol. There are a total of 9 residues, which are: Gly20, Val27, Glu143, Met146, Ile160, Asp161, Gln1291, Arg1300. These residues have significantly lower binding free energies (larger negative values), indicating a stronger affinity for ligand binding and a significant role in enhancing the stability of the DAPK1-Glu2B complex. Additionally, by analyzing the results of the alanine scanning, it can be determined that Glu100 has the greatest impact on binding free energy and is a relatively key residue in the DAPK1-Glu2B complex.
#
# Overall, the chart displays the calculated energy contributions of each residue in the simulated complex and the actual binding free energies of the top nine contributing residues, essentially showcasing the effectiveness of the simulated complex in experimental validation.
#
# Explanation of some experimental terms:
#
# - Residue: In the structure of proteins and peptides, a residue typically refers to the structural unit of an amino acid molecule. In a polypeptide chain, the carboxyl and amino groups of amino acids connect sequentially to form peptide bonds. After losing a molecule of water, a specific amino acid in the polypeptide is called a "residue." For example, a part of glutamic acid (Glu) in a polypeptide chain is referred to as a "glutamic acid residue," generally denoted by its one-letter code (E) or three-letter code (Glu).
#
# - DAPK1, Glu2B, GluN2B-CT1290-1310: DAPK1 and Glu2B are two proteins that play significant roles in the pathophysiology of depression and are considered potential targets for structure-based discovery of new antidepressants.
#
# - Simulated complex: The original paper used a combined strategy of protein-peptide docking and molecular dynamics (MD) simulation to simulate the interaction of DAPK1 with GluN2B-CT1290-1310. The complex was assessed using methods such as MD simulation, binding free energy calculation, and molecular mechanics Poisson-Boltzmann surface area (MM/GBSA).
#
# - Alanine scanning: Alanine scanning is a commonly used experimental technique for identifying important amino acid residues in proteins. By replacing an amino acid at a specific position with alanine, researchers can assess the importance of that amino acid in maintaining the protein's structure and function. The replaced residue is usually denoted by a one-letter code-number-alanine code (A).
#
# - Binding free energy:
# Binding free energy refers to the change in free energy involved when a ligand binds to its target protein. Generally, a negative binding free energy value indicates a stronger affinity between the ligand and the protein, and higher stability. The analysis of binding free energy is often used to quantify the interaction strength between two molecules and to predict the activity of the complex in the body.
#
# - Hotspot residues:
# Hotspot residues are amino acid residues that significantly affect the binding energy or function in proteins or protein complexes.
#
# - Residue naming method: In this paper, there are three main methods of residue naming. The first is the three-letter (identifying a specific amino acid)-position number format, the second is directly using the position number to represent the residue, and the third is the one-letter (identifying an amino acid)-position number-alanine number (A) format, indicating that in the alanine scanning experiment, the amino acid identified by a single letter was replaced with alanine (A).
#
# - Per-residue binding energy decomposition: Per-residue binding energy decomposition is a computational method used to determine the contribution of individual amino acid residues to the overall binding affinity of a complex. It typically includes the following steps:
#
# - Molecular dynamics; energy calculation: Using methods such as molecular mechanics/Poisson-Boltzmann surface area (MM/PBSA) or molecular mechanics/Generalized Born surface area (MM/GBSA) to calculate binding free energy and estimate the contributions of individual residues.That is, using the aforementioned methods, the total binding energy is decomposed into the contributions of each residue, highlighting the positive and negative roles.

# %%
import matplotlib.pyplot as plt
import numpy as np

residues_a = ['20', '21', '27', '100', '141', '143', '146', '160', '161','299', '301', '302', '1290', '1291', '1294', '1298', '1300', '1302','1303', '1304', '1305']
residues_b = ['E100A', 'K141A', 'R302A', 'Q1291A', 'L1298A', 'R1300A', 'H1302A', 'S1303A', 'Y1304A']
energy_contributions = [-2.02, -1.27, -1.91, -5.85, -2.79, -1.68, -0.96, -1.24, -1.47, -0.87, -0.73, -4.86, -0.97, -6.36, -0.86, -5.13, -5.93, -5.72, -2.42, -3.62, -1.64]
relative_binding_free_energy = [-19.25, -6.59, -11.03, -10.79, -2.85, -12.12, -10.93, -2.05, -7.36]

font_size = 12
x_axis_font_size = 13 

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(11, 8)) 

ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)

ax1.bar(residues_a, energy_contributions, width=0.3, color='#F38B3D')  
ax1.set_ylabel('Energy contribution (kcal/mol)', fontsize=font_size)
ax1.set_title('Residues number', fontsize=13, pad=15)
ax1.xaxis.tick_top()  
ax1.axhline(y=0, color='black', linewidth=0.5)
ax1.set_ylim(bottom=min(energy_contributions)-1, top=0) 
for i, v in enumerate(energy_contributions):
    ax1.text(i, v-0.5, f'{v:.2f}', color='black', ha='center', fontsize=10)
ax1.set_xticks(range(len(residues_a)))  
ax1.set_xticklabels(residues_a, rotation=315, ha='right', fontsize=x_axis_font_size)  # 设置x轴标签

ax1.text(-0.1, 1.05, 'A', transform=ax1.transAxes, fontsize=14, va='top', ha='right')

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)

ax2.bar(residues_b, relative_binding_free_energy, width=0.3, color='black')  # 减小柱状图宽度
ax2.set_ylabel('Relative binding free energy (kcal/mol)', fontsize=font_size)
ax2.invert_yaxis()  
ax2.set_yticks(range(-25, 1, 5))
for i, v in enumerate(relative_binding_free_energy):
    ax2.text(i, v-1, f'{v:.2f}', color='black', ha='center', fontsize=10)

ax2.set_xlabel('')

ax2.set_xticklabels(residues_b, fontsize=x_axis_font_size)

ax2.text(-0.1, 1.05, 'B', transform=ax2.transAxes, fontsize=14, va='top', ha='right')

plt.subplots_adjust(hspace=1)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_24/3407470756.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(residues_b, fontsize=x_axis_font_size)

# %% [markdown]
# # Issues with the Original Chart
# ---
#
# The bar charts of residue binding energy contributions and relative binding free energies in the paper present the results of the analysis and decomposition of the simulated DAPK1-Glu2B complex, but they are rather confusing and require the following improvements:
#
# - High information density: The original chart has a high information density, which can easily confuse readers (or other researchers). We hope that the improved chart will make the data easier to interpret.
#
# - Misaligned label positions: In the original chart, some x-axis labels (residues) in the upper and lower parts represent the energy contributions of the same residue and the relative binding free energy obtained from alanine scanning as a hotspot residue, but it is actually difficult for readers to identify the corresponding bars for the same residue above and below, affecting the readability of the experimental results.
#
# - Inconsistent residue naming: The upper labels represent residues by their position in the protein amino acid sequence, while the lower representation uses a one-letter-code-position number-alanine number (A) format to identify the relative free binding energy of different residues. Residues labeled in two different ways can easily mislead readers into thinking they are two different residues.
#
# - Inconsistent subplot directions: The energy contribution values and relative binding free energy values represented in the upper and lower parts of the original chart are both negative, but the original chart uses different directions to represent the two types of energy values, which can easily mislead readers into thinking the energy values are one positive and one negative.
#
# - Unclear comparison of calculation and scanning results: In the original chart, after calculating the binding energy contributions of 21 residues in the simulated Glu100-CT1290-1310/DAPK1 complex, the researchers selected the 9 residues with the greatest contributions and verified them through alanine scanning, but the original chart does not highlight the comparison results of the calculation and scanning results.
#
# - Label sorting does not highlight key information: The residue labels in the original chart are sorted by the position number of the amino acids, but the original chart focuses on selecting hotspot residues and displaying the relative free binding energy obtained from the scanning of the selected hotspot residues, but the original chart's sorting does not highlight the hotspot residues with greater contributions, therefore improvements are needed.
#
#
# We choose to improve this part of the chart to better support the visualization of the paper, facilitating the understanding and citation by subsequent researchers. Our work can play a certain role in lubricating the reading and research of this paper within the field.

# %%
residues_a = ['Gly20','Ser21','Val27','Glu100','Lys141', 'Glu143','Met146','Ile160', 'Asp161','Phe299','Arg301','Arg302','Ala1290','Gln1291','Asn1294','Leu1298','Arg1300','His1302','Ser1303','Tyr1304','Asp1305']
residues_b = ['Glu100', 'Lys141', 'Arg302', 'Gln1291', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304']
energy_contributions = [-2.02, -1.27, -1.91, -5.85, -2.79, -1.68, -0.96, -1.24, -1.47, -0.87, -0.73, -4.86, -0.97, -6.36, -0.86, -5.13, -5.93, -5.72, -2.42, -3.62, -1.64]
relative_binding_free_energy = [-19.25, -6.59, -11.03, -10.79, -2.85, -12.12, -10.93, -2.05, -7.36]

# 设置字体大小
font_size = 12
x_axis_font_size = 13  # x轴标签字体大小

# 对图表 A 的数据进行排序
sorted_indices_a = [i[0] for i in sorted(enumerate(energy_contributions), key=lambda x: x[1], reverse=False)]
sorted_residues_a = [residues_a[i] for i in sorted_indices_a]
sorted_energy_contributions = [energy_contributions[i] for i in sorted_indices_a]

# 对图表 B 的数据进行排序
sorted_indices_b = [i[0] for i in sorted(enumerate(relative_binding_free_energy), key=lambda x: x[1], reverse=False)]
sorted_residues_b = [residues_b[i] for i in sorted_indices_b]
sorted_relative_binding_free_energy = [relative_binding_free_energy[i] for i in sorted_indices_b]

# 创建图形和子图
fig, (ax2, ax1) = plt.subplots(2, 1, figsize=(11, 8))  # 增加图表大小，两个图表上下排列

# 图表 A
# 移除边框
for spine in ['right', 'top', 'left']:
    ax1.spines[spine].set_visible(False)

# 定义颜色列表
colors = ['#F38B3D' if residue not in ['Glu100', 'Lys141', 'Arg302', 'Gln1291', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304'] else '#5297EB' for residue in sorted_residues_a]  # 更改颜色

# 使用colors列表来设置柱状图颜色
ax1.bar(sorted_residues_a, sorted_energy_contributions, width=0.6, color=colors)
ax1.set_title('Energy contribution (kcal/mol)', fontsize=font_size, pad=20)  # y轴标签改为title

ax1.axhline(y=0, color='black', linewidth=0.5)
# 反转y轴方向
ax1.invert_yaxis()
# 添加数值标签
for i, v in enumerate(sorted_energy_contributions):
    ax1.text(i, v-0.25, f'{v:.2f}', color='black', ha='center', fontsize=10)

ax1.set_xticklabels(sorted_residues_a, rotation=335, ha='right', fontsize=7)  # 设置x轴标签

# 移除y轴刻度
ax1.yaxis.set_ticks([])


# 图表 B
# 移除边框
for spine in ['top', 'right', 'left']:
    ax2.spines[spine].set_visible(False)

ax2.bar(sorted_residues_b, sorted_relative_binding_free_energy, width=0.6, color='#5297EB')  # 减小柱状图宽度
ax2.set_title('Relative binding free energy (kcal/mol)', fontsize=font_size, pad=20)  # y轴标签改为title
ax2.invert_yaxis()  # 反转y轴方向
# 设置y轴刻度间隔为5，并包括0
ax2.set_yticks(range(-25, 1, 5))
# 添加数值标签
for i, v in enumerate(sorted_relative_binding_free_energy):
    ax2.text(i, v-1, f'{v:.2f}', color='black', ha='center', fontsize=10)

# 删除B图下方的“Residues number”
ax2.set_xlabel('')

# 设置B图x轴标签字体大小
ax2.set_xticklabels(sorted_residues_b, fontsize=x_axis_font_size)

# 移除y轴刻度
ax2.yaxis.set_ticks([])


# 增加两个子图之间的间距
plt.subplots_adjust(hspace=1)

# 展示图表
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_24/3236891028.py:42: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(sorted_residues_a, rotation=335, ha='right', fontsize=7)  # 设置x轴标签
# /tmp/ipykernel_24/3236891028.py:66: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(sorted_residues_b, fontsize=x_axis_font_size)

# %% [markdown]
# # Improved Chart 1
# ---
#
# Based on the analysis above, we made the following changes to the chart:
#
# - First, we re-sorted the energy contribution values and relative binding free energy values according to their magnitude in ascending order to more clearly display the order of residue energy contributions.
#
# - Next, we unified the x-axis labels (residues) by adopting a naming convention in the form of three-letter codes (identifying specific amino acids) followed by position numbers.
#
# - Then, we placed the sorted bar charts one above the other. Unlike the original chart, we chose to place the binding free energy of hotspot residues obtained from alanine scanning, which has a relatively smaller data set, on top. We adjusted the orientation of the bar charts and represented this data with blue bars to more easily observe the binding free energy relationships of the hotspot residues.
#
# - Finally, we placed the 21 main residues of the simulated DAPK1-Glu2B complex in the lower half, and represented the 9 residues with the greatest contributions in blue, while the remaining residues are in orange.
#
# From the optimized chart, we can draw some new conclusions:
#
# For the upper half of the chart:
# - Among the 9 residues with the greatest contributions, Glu100 has the lowest binding free energy (the largest negative value), playing the most significant role in enhancing the stability of the DAPK1-Glu2B complex and having the strongest affinity for ligand binding.
#
# - Residues Arg1300, Arg302, His1302, and Gln1291 have slightly lower binding free energies compared to Glu100, but these residues also have lower binding free energies (larger negative values), indicating a strong affinity for ligand binding and a significant role in enhancing the stability of the DAPK1-Glu2B complex. The remaining residues Tyr1304, Lys141, Leu1298, and Ser1303 have relatively smaller binding free energies compared to the previously mentioned residues.
#
# - Therefore, Glu100, Arg1300, Arg302, His1302, and Gln1291 are of greater importance in maintaining protein structure and function, while residues Tyr1304, Lys141, Leu1298, and Ser1303 play a smaller role compared to other residues. In the research process, we can prioritize the retention of the more important residues and further investigate the specific relationships between these residues and protein structure and function, thereby discovering which residues in the DAPK1-Glu2B complex are essential for maintaining protein structure and function.
#
# For the lower half of the chart:
# - Regarding the absolute binding free energy values of the 21 main residues, we can observe that Gln1291 has the greatest energy contribution at -6.36 kcal/mol, while Arg1300 has an energy contribution of -5.92 kcal/mol, and Glu100's energy contribution is the third highest at -5.85 kcal/mol.
#
# - There is a small difference in energy contributions between residues in close proximity, but overall, the difference between the maximum and minimum energy contributions of the residues is too large, with Gln1291's energy contribution being the highest at -6.36 kcal/mol, while Arg301's energy contribution is only -0.73 kcal/mol.
#
# - Therefore, we can identify Glu100, Gln1291, and Arg1300 as the most significant contributors; these residues have a higher interaction strength between the two molecules and are more active. We can focus on these residues, but residues such as Met146, Phe299, Asn1294, and Arg301 have lower contributions, less than 1 kcal/mol, indicating that these residues may not be key parts of the DAPK1-Glu2B complex.

# %%
# 数据
residues_a = ['20', '21', '27', '100', '141', '143', '146', '160', '161', '299', '301', '302', '1290', '1291', '1294', '1298', '1300', '1302', '1303', '1304', '1305']
residues_b = ['100', '141', '302', '1291', '1298', '1300', '1302', '1303', '1304']
energy_contributions = [-2.02, -1.27, -1.91, -5.85, -2.79, -1.68, -0.96, -1.24, -1.47, -0.87, -0.73, -4.86, -0.97, -6.36, -0.86, -5.13, -5.93, -5.72, -2.42, -3.62, -1.64]
relative_binding_free_energy = [-19.25, -6.59, -11.03, -10.79, -2.85, -12.12, -10.93, -2.05, -7.36]

# 设置字体大小
font_size = 12
x_axis_font_size = 13  # x轴标签字体大小

# 创建图形和子图，先创建ax2再创建ax1
fig, (ax2, ax1) = plt.subplots(2, 1, figsize=(14, 10), sharex=True, gridspec_kw={'height_ratios': [2, 3]})

# 移除边框
ax1.spines['right'].set_visible(False)
ax1.spines['bottom'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)

# 图表 B (上部)
width = 0.35  # 柱状图宽度
indices_b = [residues_a.index(r) for r in residues_b]
# 绘制相对结合自由能条形图
ax2.bar([i for i in indices_b], relative_binding_free_energy, width, color='black', alpha=0.6, label='Relative binding free energy')
ax2.set_ylabel('Relative binding free energy (kcal/mol)', fontsize=font_size)
ax2.invert_yaxis()  # 反转y轴方向
# 设置y轴刻度间隔为5，并包括0
ax2.set_yticks(range(-25, 1, 5))
# 添加数值标签
for i, v in zip(indices_b, relative_binding_free_energy):
    ax2.text(i, v-0.5, f'{v:.2f}', color='black', ha='center', fontsize=10)

# 图表 A (下部)
x = np.arange(len(residues_a))  # x轴位置
# 绘制能量贡献条形图
ax1.bar(x, energy_contributions, width, color='#F38B3D', label='Energy contribution')
ax1.set_ylabel('Energy contribution (kcal/mol)', fontsize=font_size)
ax1.axhline(y=0, color='black', linewidth=0.5)
ax1.set_ylim(bottom=min(energy_contributions)-1, top=0)  # 调整y轴范围
# 添加数值标签
for i, v in enumerate(energy_contributions):
    ax1.text(i, v-0.5, f'{v:.2f}', color='black', ha='center', fontsize=10)

# 将图表A的x轴刻度和标签移到顶部
ax1.xaxis.tick_top()
ax1.xaxis.set_label_position('top')  # 如果需要设置x轴标签位置也移到顶部

# 旋转x轴刻度并设置x轴标签
plt.xticks(x, residues_a, rotation=45, ha='right', fontsize=x_axis_font_size)  # 调整ha为'left'以适应顶部刻度

# 合并图例
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
fig.legend(lines1 + lines2, labels1 + labels2, loc='upper center', bbox_to_anchor=(0.5, 0.95), ncol=2)

# 确保布局紧凑
plt.tight_layout(rect=[0, 0, 1, 0.92])  # 调整矩形区域以留出图例空间

# 展示图表
plt.show()

# %% [markdown]
# # Improved Chart 2
# ---
#
# The method mentioned above allows us to understand the relative energy sizes of the residues, but we still cannot intuitively understand the numerical differences between the energy contributions of the top 9 hotspot residues with the greatest per-residue binding energy contributions and the binding free energy of the hotspot residues.
#
# Based on the analysis above, we made the following changes to the chart:
# - In this chart, we represent the residues by their position numbers and sort them in ascending order according to their position numbers.
#
# - In the middle section, we list all residues by number. If there are common residues in the upper and lower sub-charts, then these residues will have one bar chart facing up and one facing down.
#
# - The upward-facing part represents the binding free energy of the hotspot residues obtained from alanine scanning, while the downward-facing part represents the energy contributions of the residues. This allows us to more directly observe the differences in energy contributions and relative binding energies of the 9 hotspot residues.
#
# From the optimized chart, we can draw some new conclusions:
#
# - For most of the 9 hotspot residues, if they have a larger energy contribution, then these residues will generally also have a larger relative binding free energy value, usually showing a relationship where the relative binding free energy value is several times the energy contribution.
#
# - However, it should be noted that Leu1298 and Ser1303 do not exhibit this characteristic. The energy contribution of the Ser1303 residue is slightly larger than its relative binding free energy value, while the energy contribution of Leu1298 is more than double its relative binding free energy value.
#
# - Therefore, for Leu1298 and Ser1303, these two residues require special attention. Based on the above analysis, these two residues may not play a significant role in the stability of protein structure and function. In subsequent research, we can attempt to remove these two residues to see if it will have an impact on the protein structure and function.

# %%
# !pip install pyecharts  
# !pip install pyecharts-jupyter-plugin
# 在 Jupyter Notebook 中确保渲染为 HTML  
# %matplotlib inline
from pyecharts import options as opts  
from pyecharts.charts import Bar, Grid  
from pyecharts.commons.utils import JsCode  
from IPython.display import display  

# 数据  
residues_a = ['Gly20', 'Ser21', 'Val27', 'Glu100', 'Lys141', 'Egl143', 'Met146', 'Ile160', 'Asp161', 'Phe299', 'Arg301', 'Arg302', 'Ala1290', 'Gln1291', 'Asn1294', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304', 'Asp1305']  
residues_b = ['Glu100', 'Lys141', 'Arg302', 'Gln1291', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304']  
energy_contributions = [-2.02, -1.27, -1.91, -5.85, -2.79, -1.68, -0.96, -1.24, -1.47, -0.87, -0.73, -4.86, -0.97, -6.36, -0.86, -5.13, -5.93, -5.72, -2.42, -3.62, -1.64]  
relative_binding_free_energy = [-19.25, -6.59, -11.03, -10.79, -2.85, -12.12, -10.93, -2.05, -7.36]  

# 对图表 A 的数据进行排序  
sorted_indices_a = [i for i, _ in sorted(enumerate(energy_contributions), key=lambda x: x[1])]  
sorted_residues_a = [residues_a[i] for i in sorted_indices_a]  
sorted_energy_contributions = [energy_contributions[i] for i in sorted_indices_a]  

# 对图表 B 的数据进行排序  
sorted_indices_b = [i for i, _ in sorted(enumerate(relative_binding_free_energy), key=lambda x: x[1])]  
sorted_residues_b = [residues_b[i] for i in sorted_indices_b]  
sorted_relative_binding_free_energy = [relative_binding_free_energy[i] for i in sorted_indices_b]  

# 创建图表 A  
bar_a = (  
    Bar()  
    .add_xaxis(sorted_residues_a)  
    .add_yaxis(  
        "Energy contribution (kcal/mol)",  
        sorted_energy_contributions,  
        itemstyle_opts=opts.ItemStyleOpts(  
            color=JsCode("""  
                function(params) {  
                    var residues_b = ['Glu100', 'Lys141', 'Arg302', 'Gln1291', 'Leu1298',   
                                     'Arg1300', 'His1302', 'Ser1303', 'Tyr1304'];  
                    return residues_b.includes(params.name) ? '#5297EB' : '#F38B3D';  
                }  
            """)  
        ),  
        label_opts=opts.LabelOpts(is_show=True, position="top", font_size=10),  
    )  
    .set_global_opts(  
        title_opts=opts.TitleOpts(title="Energy contribution (kcal/mol)", pos_top="55%", pos_left="center"),  
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(rotate=-35, font_size=7), axisline_opts=opts.AxisLineOpts(is_show=False), axistick_opts=opts.AxisTickOpts(is_show=False)),  
        yaxis_opts=opts.AxisOpts(is_inverse=True, is_show=False),  
        toolbox_opts=opts.ToolboxOpts(is_show=True),  
        legend_opts=opts.LegendOpts(is_show=False),  
    )  
)  

# 创建图表 B  
bar_b = (  
    Bar()  
    .add_xaxis(sorted_residues_b)  
    .add_yaxis(  
        "Relative binding free energy (kcal/mol)",  
        sorted_relative_binding_free_energy,  
        itemstyle_opts=opts.ItemStyleOpts(color='#5297EB'),  
        label_opts=opts.LabelOpts(is_show=True, position="top", font_size=10),  
    )  
    .set_global_opts(  
        title_opts=opts.TitleOpts(title="Relative binding free energy (kcal/mol)", pos_top="1%", pos_left="center"),  
        xaxis_opts=opts.AxisOpts(axislabel_opts=opts.LabelOpts(font_size=13), axisline_opts=opts.AxisLineOpts(is_show=False), axistick_opts=opts.AxisTickOpts(is_show=False)),  
        yaxis_opts=opts.AxisOpts(is_inverse=True, is_show=False),  
        toolbox_opts=opts.ToolboxOpts(is_show=True),  
        legend_opts=opts.LegendOpts(is_show=False),  
    )  
)  

# 组合两个图表  
grid = (  
    Grid()  
    .add(bar_a, grid_opts=opts.GridOpts(pos_left="5%", pos_right="5%", pos_bottom="50%"))  
    .add(bar_b, grid_opts=opts.GridOpts(pos_left="5%", pos_right="5%", pos_top="50%"))  
)  

# 显示图表  
display(grid.render_notebook())
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ae2bed2e73034b8cb17bdeda0c0ba4fa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ae2bed2e73034b8cb17bdeda0c0ba4fa = echarts.init(
#                     document.getElementById('ae2bed2e73034b8cb17bdeda0c0ba4fa'), 'white', {renderer: 'canvas'});
#                 var option_ae2bed2e73034b8cb17bdeda0c0ba4fa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %% [markdown]
# # Improved Chart 3
# ---
#
# We have made dynamic modifications to the chart as follows:
# - Unified the x-axis naming according to the format of three-letter codes (identifying specific amino acids) followed by position numbers.
#
# - Here, we place the 21 main residues in the upper half, sorted in ascending order by value, with the 9 hotspot residues represented by blue bars and the rest by orange bars.
#
# - The 9 residues with the greatest contributions are placed in the lower half, sorted in ascending order by value, and represented by blue bars.
#
# - By hovering the mouse over each bar, we can obtain a specific description of that bar, including the name of the residue, the name of the described value (such as relative binding free energy, energy contribution), the corresponding unit, and the specific value.
#
# This method has numerous advantages:
# - It simplifies the image, making it more convenient to read.
#
# - For scientific researchers, it helps them to obtain the information they want more quickly.
#
# - The distribution of information is more logical; the ascending order allows for a more specific display of the differences in free binding energy and energy contributions across different residues within the chart.

# %%
import dash
from dash import dcc, html, callback_context
from dash.dependencies import Input, Output, State
import plotly.graph_objects as go
import copy

# 数据
residues_a = ['Gly20', 'Ser21', 'Val27', 'Glu100', 'Lys141', 'Egl143', 'Met146', 'Ile160', 'Asp161', 'Phe299', 'Arg301', 'Arg302', 'Ala1290', 'Gln1291', 'Asn1294', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304', 'Asp1305']
residues_b = ['Glu100', 'Lys141', 'Arg302', 'Gln1291', 'Leu1298', 'Arg1300', 'His1302', 'Ser1303', 'Tyr1304']
energy_contributions = [-2.02, -1.27, -1.91, -5.85, -2.79, -1.68, -0.96, -1.24, -1.47, -0.87, -0.73, -4.86, -0.97, -6.36, -0.86, -5.13, -5.93, -5.72, -2.42, -3.62, -1.64]
relative_binding_free_energy = [-19.25, -6.59, -11.03, -10.79, -2.85, -12.12, -10.93, -2.05, -7.36]

# 对图表 A 进行排序
sorted_indices_a = [i for i, _ in sorted(enumerate(energy_contributions), key=lambda x: x[1])]
sorted_residues_a = [residues_a[i] for i in sorted_indices_a]
sorted_energy_contributions = [energy_contributions[i] for i in sorted_indices_a]

# 对图表 B 进行排序
sorted_indices_b = [i for i, _ in sorted(enumerate(relative_binding_free_energy), key=lambda x: x[1])]
sorted_residues_b = [residues_b[i] for i in sorted_indices_b]
sorted_relative_binding_free_energy = [relative_binding_free_energy[i] for i in sorted_indices_b]

# 创建图表 A
fig_a_base = go.Figure(go.Bar(
    x=sorted_residues_a,
    y=sorted_energy_contributions,
    name="Energy contribution (kcal/mol)",
    marker_color=['#F38B3D' if r not in residues_b else '#5297EB' for r in sorted_residues_a],
    hovertemplate='Residue: %{x}<br>Energy Contribution: %{y:.2f} kcal/mol<extra></extra>',
    text=[f'{y:.2f}' for y in sorted_energy_contributions],  # 显示数值标签
    textposition='outside',
    orientation='v',
))

# 图表 A 的布局
fig_a_base.update_layout(
    title="Energy contribution (kcal/mol)",
    title_x=0.5,
    title_font=dict(size=20, color='#4C4F4C', family='Arial', weight='bold'),
    yaxis=dict(
        autorange="reversed",  # 翻转 Y 轴
        showticklabels=False,  # 隐藏 Y 轴刻度
        showgrid=False,  # 隐藏 Y 轴网格
        visible=False,  # 隐藏 Y 轴
        zeroline=True,  # 显示零线
        zerolinecolor='black',  # 设置零线颜色为黑色
        zerolinewidth=2,  # 设置零线宽度
        range=[-7, 0],  # 确保 Y 轴范围包含 0
    ),
    xaxis=dict(
        showgrid=False,  # 隐藏 X 轴网格
        visible=True,  # 确保 X 轴可见
        tickfont=dict(size=9),  # 调整 X 轴标签字体大小
    ),
    plot_bgcolor='rgba(0,0,0,0)', 
    paper_bgcolor='rgba(0,0,0,0)', 
    margin=dict(l=20, r=20, t=50, b=20), 
    shapes=[ 
        dict(
            type='line',
            xref='paper',
            yref='y',
            x0=0,
            x1=1,
            y0=0,
            y1=0,
            line=dict(color='black', width=1)
        )
    ]
)

# 创建图表 B
fig_b_base = go.Figure(go.Bar(
    x=sorted_residues_b,
    y=sorted_relative_binding_free_energy,
    name="Relative binding free energy (kcal/mol)",
    marker_color='#5297EB',
    hovertemplate='Residue: %{x}<br>Relative Binding Free Energy: %{y:.2f} kcal/mol<extra></extra>',
    text=[f'{y:.2f}' for y in sorted_relative_binding_free_energy],  # 显示数值标签
    textposition='outside',
    orientation='v',
))

# 图表 B 的布局
fig_b_base.update_layout(
    title="Relative binding free energy (kcal/mol)",
    title_x=0.5,
    title_font=dict(size=20, color='#4C4F4C', family='Arial', weight='bold'),
    yaxis=dict(
        autorange="reversed",  # 翻转 Y 轴
        showticklabels=False,  # 隐藏 Y 轴刻度
        showgrid=False,  # 隐藏 Y 轴网格
        visible=False,  # 隐藏 Y 轴
        zeroline=True,  # 显示零线
        zerolinecolor='black',  # 设置零线颜色为黑色
        zerolinewidth=2,  # 设置零线宽度
        range=[-20, 0],  # 确保 Y 轴范围包含 0
    ),
    xaxis=dict(
        showgrid=False,  # 隐藏 X 轴网格
        visible=True,  # 确保 X 轴可见
        tickfont=dict(size=14),  # 调整 X 轴标签字体大小
    ),
    plot_bgcolor='rgba(0,0,0,0)', 
    paper_bgcolor='rgba(0,0,0,0)', 
    margin=dict(l=20, r=20, t=50, b=20), 
    shapes=[ 
        dict(
            type='line',
            xref='paper',
            yref='y',
            x0=0,
            x1=1,
            y0=0,
            y1=0,
            line=dict(color='black', width=1)
        )
    ]
)

app = dash.Dash(__name__)

app.layout = html.Div([
    html.Div([  # 图 B 在上方
        dcc.Graph(id='graph-b', figure=fig_b_base, style={'width': '650px', 'height': '390px'}),
    ], style={'margin': '15px'}),
    
    html.Div([  # 图 A 在下方
        dcc.Graph(id='graph-a', figure=fig_a_base, style={'width': '900px', 'height': '350px'}),
    ], style={'margin': '15px'}),
])

# 使用 State 来存储当前的悬停状态
@app.callback(
    [Output('graph-a', 'figure'),
     Output('graph-b', 'figure')],
    [Input('graph-a', 'hoverData'),
     Input('graph-b', 'hoverData')],
    [State('graph-a', 'hoverData'),
     State('graph-b', 'hoverData')]
)
def update_graphs(hoverDataA, hoverDataB, state_hoverDataA, state_hoverDataB):
    ctx = callback_context
    triggered_id = ctx.triggered[0]['prop_id'].split('.')[0]

    # 如果没有悬停数据，返回原始图表
    if not any([hoverDataA, hoverDataB]):
        return fig_a_base, fig_b_base

    # 获取当前悬停的残基名称
    hovered_residue = None
    if triggered_id == 'graph-a' and hoverDataA:
        hovered_residue = hoverDataA['points'][0]['x']
    elif triggered_id == 'graph-b' and hoverDataB:
        hovered_residue = hoverDataB['points'][0]['x']

    # 更新图表 A
    fig_a = copy.deepcopy(fig_a_base)
    fig_a.update_traces(marker_color=[
        ('#FCEDBE' if r == hovered_residue and r not in residues_b else 
         '#C8D5F6' if r == hovered_residue else 
         ('#F38B3D' if r not in residues_b else '#5297EB')) 
        for r in sorted_residues_a
    ])

    # 更新图表 B
    fig_b = copy.deepcopy(fig_b_base)
    fig_b.update_traces(marker_color=[
        ('#C8D5F6' if r == hovered_residue else '#5297EB') 
        for r in sorted_residues_b
    ])

    return fig_a, fig_b

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# # Conclusion
# ---
#
# We have improved a chart within a medical article that includes the calculated energy contributions of each residue and the actual free binding energy of the top 9 contributing hotspot residues in a simulated complex, which has a certain effect on the treatment of depression. However, there were some issues with the way the chart was presented, so we hope to provide convenience for scientific researchers by improving the image.
#
# In the process of analyzing this chart, we found that it had issues such as high information density, misaligned label positions, inconsistent residue naming, inconsistent subplot directions, unclear comparison between calculation and scanning results, and label sorting that did not highlight key information.
#
# We improved the chart by reordering it according to the value size, unifying the format naming of labels (residues), reconstructing the distribution of the bar chart, unifying the direction, choosing more appropriate colors, and dynamizing the image.
#
# By observing the improved chart, we can draw the following conclusions: Glu100, Arg1300, Arg302, His1302, and Gln1291 play a significant role in enhancing the stability of the DAPK1-Glu2B complex, have the strongest affinity for ligand binding, and may be crucial for maintaining protein function and structure. However, for Leu1298 and Ser1303, the energy contribution is slightly larger than the relative binding free energy value, and they may not be significant in maintaining protein function and structure. It is suggested that scientific researchers can try to eliminate these two components in subsequent work.
